# %% [markdown]
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Content/media/DU_Logo.svg' width="250" height="300"/></a>
# <pre>
# <center><b><h1>Machine Learning - 2301CS621</b></center>
#
# <center><b><h1>Lab - 2 (Cardiovascular Disease Analysis)</b></center>
# <pre>

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %% [markdown]
# ### Step 2. Import the dataset from 'cardio_train.csv/cardio_train.csv' and assign it to a variable called df

# %% [markdown]
# ### Step 3. Display the first 5 entries of the dataset

# %% [markdown]
# ### Step 4. Display the last 5 entries of the dataset

# %% [markdown]
# ### Step 5. What is the number of observations (rows) in the dataset?

# %% [markdown]
# ### Step 6. What is the number of columns in the dataset?

# %% [markdown]
# ### Step 7. Print the name of all the columns.

# %% [markdown]
# ### Step 8. What is the data type of each column?

# %% [markdown]
# ### Step 9. Show the basic summary statistics (describe) of the dataset.

# %% [markdown]
# ### Step 10. Check if there are any missing (null) values in the dataset.

# %% [markdown]
# ### Step 11. How many patients have cardiovascular disease (cardio = 1) and how many do not (cardio = 0)?

# %% [markdown]
# ### Step 12. What is the average age of patients in years? (Convert age in days to years by dividing by 365.25)

# %% [markdown]
# ### Step 13. What is the average weight of the patients in the dataset?

# %% [markdown]
# ### Step 14. What are the maximum and minimum systolic blood pressure (ap_hi) values recorded?

# %% [markdown]
# ### Step 15. How many male and female patients are in the dataset? (gender is coded as 1 and 2)

# %% [markdown]
# ### Step 16. What is the average height of patients who smoke (smoke == 1) compared to those who do not smoke (smoke == 0)?

# %% [markdown]
# ### Step 17. Find the percentage of patients who are physically active (active == 1).

# %% [markdown]
# ### Step 18. Filter the dataset to show only patients who have both high cholesterol (cholesterol == 3) and high glucose (gluc == 3).

# %% [markdown]
# ### Step 19. Group the dataset by cardiovascular disease status (cardio) and find the mean values of systolic (ap_hi) and diastolic (ap_lo) blood pressure for each group.

# %% [markdown]
# ### Step 20. Calculate the Body Mass Index (BMI) for each patient: BMI = weight / (height/100)^2. Add this as a new column 'BMI' and display the first 5 rows.
