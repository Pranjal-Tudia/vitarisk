# %% [markdown]
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Content/media/DU_Logo.svg' width="250" height="300"/></a>
# <pre>
# <center><b><h1>Machine Learning - 2301CS621</b></center>
#
# <center><b><h1>Project : Cardiovascular Disease Dataset</b></center>
# <center><b><h3>Week 1: Problem Definition and Dataset Exploration</h3></b></center>
# <pre>

# %% [markdown]
# ### Step 1. Problem Statement
# The objective of this project is to build a machine learning model that predicts the presence or absence of cardiovascular disease in patients based on their physical, clinical, and lifestyle examination data (such as age, systolic/diastolic blood pressure, cholesterol, glucose levels, smoking habits, alcohol intake, and physical activity). Early detection of cardiovascular risk helps in timely medical intervention and lifestyle modification.

# %% [markdown]
# ### Step 2. Import necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Step 3. Load the raw dataset

# %%
df = pd.read_csv('cardio_train.csv/cardio_train.csv', sep=';')
df.head()
# Out:
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393       2     168    62.0    110     80            1     1      0
# 1   1  20228       1     156    85.0    140     90            3     1      0
# 2   2  18857       1     165    64.0    130     70            3     1      0
# 3   3  17623       2     169    82.0    150    100            1     1      0
# 4   4  17474       1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       0       1
# 3     0       1       1
# 4     0       0       0

# %% [markdown]
# ### Step 4. Dataset Summary and Structure

# %%
print("Dataset Dimensions (Rows, Columns):", df.shape)
print("\nDataset Info:")
df.info()
# Out:
# Dataset Dimensions (Rows, Columns): (70000, 13)
#
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70000 entries, 0 to 69999
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           70000 non-null  int64
#  1   age          70000 non-null  int64
#  2   gender       70000 non-null  int64
#  3   height       70000 non-null  int64
#  4   weight       70000 non-null  float64
#  5   ap_hi        70000 non-null  int64
#  6   ap_lo        70000 non-null  int64
#  7   cholesterol  70000 non-null  int64
#  8   gluc         70000 non-null  int64
#  9   smoke        70000 non-null  int64
#  10  alco         70000 non-null  int64
#  11  active       70000 non-null  int64
#  12  cardio       70000 non-null  int64
# dtypes: float64(1), int64(12)
# memory usage: 6.9 MB

# %% [markdown]
# ### Step 5. Descriptive Statistics of Features

# %%
df.describe()
# Out:
#                  id           age        gender        height        weight  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean   49972.419900  19468.865814      1.349571    164.359229     74.205690
# std    28851.302323   2467.251667      0.476838      8.210126     14.395757
# min        0.000000  10798.000000      1.000000     55.000000     10.000000
# 25%    25006.750000  17664.000000      1.000000    159.000000     65.000000
# 50%    50001.500000  19703.000000      1.000000    165.000000     72.000000
# 75%    74889.250000  21327.000000      2.000000    170.000000     82.000000
# max    99999.000000  23713.000000      2.000000    250.000000    200.000000
#
#               ap_hi         ap_lo   cholesterol          gluc         smoke  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean     128.817286     96.630414      1.366871      1.226457      0.088129
# ...

# %% [markdown]
# ### Step 6. Check for Missing and Null Values

# %%
print("Missing values in each column:")
print(df.isnull().sum())
# Out:
# Missing values in each column:
# id             0
# age            0
# gender         0
# height         0
# weight         0
# ap_hi          0
# ap_lo          0
# cholesterol    0
# gluc           0
# smoke          0
# alco           0
# active         0
# cardio         0
# dtype: int64

# %% [markdown]
# ### Step 7. Check Target Variable Distribution (`cardio`)

# %%
print("Target Distribution:")
print(df['cardio'].value_counts())
print("\nPercentage Distribution:")
print(df['cardio'].value_counts(normalize=True) * 100)
# Out:
# Target Distribution:
# cardio
# 0    35021
# 1    34979
# Name: count, dtype: int64
#
# Percentage Distribution:
# cardio
# 0    50.03
# 1    49.97
# Name: proportion, dtype: float64

# %% [markdown]
# ### Step 8. Initial Observations

# %% [markdown]
# 1. **Dataset Size:** 70,000 patient records across 13 columns.
# 2. **Missing Values:** No null or missing values are present.
# 3. **Target Balance:** Target variable `cardio` is evenly balanced (~50% presence, ~50% absence).
# 4. **Age Unit:** Age is measured in days and needs conversion to years in preprocessing.
# 5. **Outliers:** Blood pressure and weight columns contain anomalous values that require cleaning in Week 2.
